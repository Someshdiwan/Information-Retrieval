# %%
# !pip install requests
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\somes\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\somes\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\somes\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\somes\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\somes\anaconda3\lib\site-packages (from requests) (2024.12.14)
# Requirement already satisfied: beautifulsoup4 in c:\users\somes\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\somes\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

def crawl_webpage(url, max_depth=3, allowed_domains=None):
    visited_urls = set()  # Set to track visited URLs
    urls_to_visit = [(url, 0)]  # Initialize the list of URLs to visit, starting from the input URL
    
    while urls_to_visit:
        current_url, depth = urls_to_visit.pop(0)  # Pop the next URL to visit
        if current_url in visited_urls or depth > max_depth:  # Skip if already visited or max depth exceeded
            continue
        
        print(f"Crawling: {current_url} (Depth: {depth})")  # Print the URL being crawled
        try:
            response = requests.get(current_url)  # Get the response from the URL
            if response.status_code == 200:  # If the page was fetched successfully
                visited_urls.add(current_url)  # Mark URL as visited
                soup = BeautifulSoup(response.text, "html.parser")  # Parse the page content
                
                # Extract all the links from the page
                for link in soup.find_all("a"):
                    link_href = link.get("href")
                    if link_href:
                        absolute_link = urljoin(current_url, link_href)  # Get the absolute URL
                        parsed_link = urlparse(absolute_link)  # Parse the link to check its domain
                        
                        # Print the found link
                        print(f"Found link: {absolute_link}")
                        
                        # If allowed_domains is specified, check if the domain of the link is allowed
                        if allowed_domains:
                            if parsed_link.netloc in allowed_domains:
                                urls_to_visit.append((absolute_link, depth + 1))  # Add the link to visit
                        else:
                            # If no domain filter, visit any link
                            urls_to_visit.append((absolute_link, depth + 1))
        except Exception as e:
            print(f"Error crawling {current_url}: {e}")  # Handle exceptions

# Start crawling from a specific URL and limit the crawl to specific websites
start_url = "https://www.bbc.com"
allowed_domains = ["bbc.com"]  # Only crawl within bbc.com
crawl_webpage(start_url, max_depth=3, allowed_domains=allowed_domains)
# Out:
# Crawling: https://www.bbc.com (Depth: 0)
# Found link: https://www.bbc.com#main-content
# Found link: https://www.bbc.com/
# Found link: https://www.bbc.com/
# Found link: https://www.bbc.com/news
# Found link: https://www.bbc.com/sport
# Found link: https://www.bbc.com/business
# Found link: https://www.bbc.com/innovation
# Found link: https://www.bbc.com/culture
# Found link: https://www.bbc.com/arts
# Found link: https://www.bbc.com/travel
# Found link: https://www.bbc.com/future-planet
# Found link: https://www.bbc.com/video
# Found link: https://www.bbc.com/live
# Found link: https://www.bbc.com/home
# Found link: https://www.bbc.com/news
# Found link: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# Found link: https://www.bbc.com/news/war-in-ukraine
# Found link: https://www.bbc.com/news/us-canada
# Found link: https://www.bbc.com/news/uk
# Found link: https://www.bbc.com/news/politics
# Found link: https://www.bbc.com/news/england
# Found link: https://www.bbc.com/news/northern_ireland
# Found link: https://www.bbc.com/news/northern_ireland/northern_ireland_politics
# Found link: https://www.bbc.com/news/scotland
# Found link: https://www.bbc.com/news/scotland/scotland_politics
# Found link: https://www.bbc.com/news/wales
# Found link: https://www.bbc.com/news/wales/wales_politics
# Found link: https://www.bbc.com/news/world/africa
# Found link: https://www.bbc.com/news/world/asia
# Found link: https://www.bbc.com/news/world/asia/china
# Found link: https://www.bbc.com/news/world/asia/india
# Found link: https://www.bbc.com/news/world/australia
# Found link: https://www.bbc.com/news/world/europe
# Found link: https://www.bbc.com/news/world/latin_america
# Found link: https://www.bbc.com/news/world/middle_east
# Found link: https://www.bbc.com/news/in_pictures
# Found link: https://www.bbc.com/news/bbcindepth
# Found link: https://www.bbc.com/news/reality_check
# Found link: https://www.bbc.com/sport
# Found link: https://www.bbc.com/business
# Found link: https://www.bbc.com/business/executive-lounge
# Found link: https://www.bbc.com/business/technology-of-business
# Found link: https://www.bbc.com/business/future-of-business
# Found link: https://www.bbc.com/innovation
# Found link: https://www.bbc.com/innovation/technology
# Found link: https://www.bbc.com/innovation/science
# Found link: https://www.bbc.com/innovation/artificial-intelligence
# Found link: https://www.bbc.com/innovation/ai-v-the-mind
# Found link: https://www.bbc.com/culture
# Found link: https://www.bbc.com/culture/film-tv
# Found link: https://www.bbc.com/culture/music
# Found link: https://www.bbc.com/culture/art
# Found link: https://www.bbc.com/culture/style
# Found link: https://www.bbc.com/culture/books
# Found link: https://www.bbc.com/culture/entertainment-news
# Found link: https://www.bbc.com/arts
# Found link: https://www.bbc.com/arts/arts-in-motion
# Found link: https://www.bbc.com/travel
# Found link: https://www.bbc.com/travel/destinations
# Found link: https://www.bbc.com/travel/destinations/africa
# Found link: https://www.bbc.com/travel/destinations/antarctica
# Found link: https://www.bbc.com/travel/destinations/asia
# Found link: https://www.bbc.com/travel/destinations/australia-and-pacific
# Found link: https://www.bbc.com/travel/destinations/caribbean
# Found link: https://www.bbc.com/travel/destinations/central-america
# Found link: https://www.bbc.com/travel/destinations/europe
# Found link: https://www.bbc.com/travel/destinations/middle-east
# Found link: https://www.bbc.com/travel/destinations/north-america
# Found link: https://www.bbc.com/travel/destinations/south-america
# Found link: https://www.bbc.com/travel/worlds-table
# Found link: https://www.bbc.com/travel/cultural-experiences
# Found link: https://www.bbc.com/travel/adventures
# Found link: https://www.bbc.com/travel/specialist
# Found link: https://www.bbc.com/future-planet
# Found link: https://www.bbc.com/future-planet/natural-wonders
# Found link: https://www.bbc.com/future-planet/weather-science
# Found link: https://www.bbc.com/future-planet/solutions
# Found link: https://www.bbc.com/future-planet/sustainable-business
# Found link: https://www.bbc.com/future-planet/green-living
# Found link: https://www.bbc.com/video
# Found link: https://www.bbc.com/live
# Found link: https://www.bbc.com/live/news
# Found link: https://www.bbc.com/live/sport
# Found link: https://www.bbc.com/
# Found link: https://www.bbc.com/sport
# Found link: https://www.bbc.com/video
# Found link: https://www.bbc.co.uk/sounds
# Found link: https://www.bbc.com/weather
# Found link: https://www.bbc.com/newsletters
# Found link: https://www.bbc.com/news/articles/c878ryr04p8o
# Found link: https://www.bbc.com/news/articles/cyv3rl9prp6o
# Found link: https://www.bbc.com/news/articles/c878ryr04p8o
# Found link: https://www.bbc.com/news/articles/cyv3rl9prp6o
# Found link: https://www.bbc.com/news/articles/c3rqg95n9n1o
# Found link: https://www.bbc.com/news/articles/crrwyv75g5xo
# Found link: https://www.bbc.com/news/articles/c5yv10knyd9o
# Found link: https://www.bbc.com/news/articles/cr56gr6p49eo
# Found link: https://www.bbc.com/news/articles/c9q78wn9g8zo
# Found link: https://www.bbc.com/culture/article/20250106-golden-globes-how-shock-wins-have-shaken-up-the-oscars-race
# Found link: https://www.bbc.com/travel/article/20250106-the-seven-travel-trends-that-will-shape-2025
# Found link: https://www.bbc.com/news
# Found link: https://www.bbc.com/news/articles/c89xz21zqdzo
# Found link: https://www.bbc.com/news/articles/cy9q7lvj34ro
# Found link: https://www.bbc.com/news/articles/c9wlzz9179do
# Found link: https://www.bbc.com/news/articles/cvg72pdvw1ro
# Found link: https://www.bbc.com/news/articles/cge93de21n0o
# Found link: https://www.bbc.com/news/videos/c3rqgwxwl2yo
# Found link: https://www.bbc.com/news/videos/c5yd157rl21o
# Found link: https://www.bbc.com/news/videos/c62wyyxyey6o
# Found link: https://www.bbc.com/news/videos/c3vrgkdk9q3o
# Found link: https://www.bbc.com/news/videos/c1elx48e56eo
# Found link: https://www.bbc.com/reel/video/p0kftjyg/homo-juluensis-possible-new-ancient-human-identified
# Found link: https://www.bbc.com/news/videos/cd75139py5go
# Found link: https://www.bbc.com/news/videos/cz0rvky8434o
# Found link: https://www.bbc.com/innovation/technology
# Found link: https://www.bbc.com/news/articles/c4g5v8klkqvo
# Found link: https://www.bbc.com/future/article/20250103-a-four-day-guide-to-forging-better-friendships-to-improve-your-life
# Found link: https://www.bbc.com/future/article/20240126-why-power-naps-might-be-good-for-our-health
# Found link: https://www.bbc.com/future/article/20230823-the-curious-ways-your-skin-shapes-your-health
# Found link: https://www.bbc.com/future/article/20230120-how-gut-bacteria-are-controlling-your-brain
# Found link: https://cloud.email.bbc.com/SixStepstoCalm_Newsletter_Signup?&at_bbc_team=studios&at_medium=emails&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.com&at_format=Module&at_link_origin=homepage&at_campaign=sscalm&at_campaign_type=owned
# Found link: https://bbc-global.onelink.me/Ezi6/n4y4nlv7
# Found link: https://cloud.email.bbc.com/FutureEarth_Newsletter_Signup?&at_bbc_team=studios&at_medium=display&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.comhp&at_format=Module&at_link_origin=homepage&at_campaign=futureearth&at_campaign_type=owned
# Found link: https://www.bbc.co.uk/programmes/w13xtvsd
# Found link: https://account.bbc.com/auth/register/email?ab=o13&action=register&clientId=Account&context=international&isCasso=false&nonce=ZhRJnl8N-Nzg4mlepfcUAP3WaQY2IhgqHUUw&ptrt=https%3A%2F%2Fwww.bbc.com%2F&realm=%2F&redirectUri=https%3A%2F%2Fsession.bbc.com%2Fsession%2Fcallback%3Frealm%3D%2F&sequenceId=afd616da-9f13-432d-a54d-95c9f32d1f0b&service=IdRegisterService&userOrigin=BBCS_BBC
# Found link: https://cloud.email.bbc.com/SignUp10_08?&at_bbc_team=studios&at_medium=display&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.comhp&at_format=Module&at_link_origin=homepage&at_campaign=essentiallist&at_campaign_type=owned
# Found link: https://cloud.email.bbc.com/bbcnewsignup2?&at_bbc_team=studios&at_medium=display&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.comhp&at_format=Module&at_link_origin=homepage&at_campaign=newsbriefing&at_campaign_type=owned
# Found link: https://www.bbc.com/news/us-canada
# Found link: https://www.bbc.com/news/videos/cr7vg45y0g7o
# Found link: https://www.bbc.com/news/articles/c627p8leww1o
# Found link: https://www.bbc.com/news/articles/ckg3k2v11k5o
# Found link: https://www.bbc.com/news/articles/c75ngl49695o
# Found link: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# Found link: https://www.bbc.com/news/articles/cly7men0z44o
# Found link: https://www.bbc.com/news/articles/c0ewr870z23o
# Found link: https://www.bbc.com/news/articles/cz9g4yl8j17o
# Found link: https://www.bbc.com/news/articles/cj30zk1jnmno
# Found link: https://www.bbc.com/news/war-in-ukraine
# Found link: https://www.bbc.com/news/articles/cr56gr6p49eo
# Found link: https://www.bbc.com/news/articles/c86wz0vd1dwo
# Found link: https://www.bbc.com/news/articles/cpw245qpezwo
# Found link: https://www.bbc.com/news/articles/c0mve9kng72o
# Found link: https://www.bbc.com/news/world
# Found link: https://www.bbc.com/news/articles/c9vkyk3v02xo
# Found link: https://www.bbc.com/news/articles/cr7vg535vvro
# Found link: https://www.bbc.com/news/articles/ced8q1yxggqo
# Found link: https://www.bbc.com/news/articles/c74x28k7987o
# Found link: https://www.bbc.com/video
# Found link: https://www.bbc.com/reel/video/p0kftjyg/homo-juluensis-possible-new-ancient-human-identified
# Found link: https://www.bbc.com/sport
# Found link: https://www.bbc.com/sport/football/articles/c0j1xzg5eqqo
# Found link: https://www.bbc.com/sport/football/articles/c708p0d546po
# Found link: https://www.bbc.com/sport/football/articles/cy53x316kzgo
# Found link: https://www.bbc.com/sport/cricket/articles/c9wl9lep7w5o
# Found link: https://www.bbc.com/business
# Found link: https://www.bbc.com/news/articles/c9q78wn9g8zo
# Found link: https://www.bbc.com/news/articles/c0q0jl8pl9ko
# Found link: https://www.bbc.com/news/articles/c627p8leww1o
# Found link: https://www.bbc.com/news/articles/c75ngl49695o
# Found link: https://www.bbc.com/innovation/technology
# Found link: https://www.bbc.com/news/articles/cx2vz60vjyqo
# Found link: https://www.bbc.com/news/articles/c7ve4m1q42vo
# Found link: https://www.bbc.com/news/articles/c5ydj07r0gro
# Found link: https://www.bbc.com/news/articles/cr4rkz5nz69o
# Found link: https://www.bbc.com/innovation/science
# Found link: https://www.bbc.com/news/articles/c93gxgevrdwo
# Found link: https://www.bbc.com/news/articles/c4glj87gz0xo
# Found link: https://www.bbc.com/future/article/20250103-what-people-living-in-the-arctic-polar-night-teach-us-about-sleep
# Found link: https://www.bbc.com/news/articles/c1wq15zwlr8o
# Found link: https://www.bbc.com/culture
# Found link: https://www.bbc.com/news/articles/cvg6m07qpymo
# Found link: https://www.bbc.com/news/articles/cz0rvk17vy3o
# Found link: https://www.bbc.com/news/articles/cr56933dq2do
# Found link: https://www.bbc.com/news/articles/ckgx2w78ppwo
# Found link: https://www.bbc.com/arts
# Found link: https://www.bbc.com/news/articles/cn0xr33dj4po
# Found link: https://www.bbc.com/news/articles/c0lg6151p32o
# Found link: https://www.bbc.com/reel/video/p0kcpvgr/the-technology-powering-the-iconic-sydney-opera-house
# Found link: https://www.bbc.com/news/articles/c0rn7eljy12o
# Found link: https://www.bbc.com/travel
# Found link: https://www.bbc.com/travel/article/20250103-thunder-tea-rice-the-2000-year-old-healthy-grain-bowl
# Found link: https://www.bbc.com/travel/article/20241230-a-family-friendly-guide-to-brisbane-australia-with-blueys-mum
# Found link: https://www.bbc.com/travel/article/20241231-travel-in-2025-longer-trips-to-fewer-places
# Found link: https://www.bbc.com/travel/article/20250102-the-new-travel-retreats-addressing-depression-and-grief
# Found link: https://www.bbc.com/future-planet
# Found link: https://www.bbc.com/news/articles/c17dx4v5plvo
# Found link: https://www.bbc.com/news/articles/clyvexpew8zo
# Found link: https://www.bbc.com/future/article/20250103-clay-grass-plastic-and-glass-the-materials-making-caribbean-houses-more-climate-resilient
# Found link: https://www.bbc.com/news/articles/c0kvlkvzdgzo
# Found link: https://www.bbc.com/
# Found link: https://www.bbc.com/
# Found link: https://www.bbc.com/news
# Found link: https://www.bbc.com/sport
# Found link: https://www.bbc.com/business
# Found link: https://www.bbc.com/innovation
# Found link: https://www.bbc.com/culture
# Found link: https://www.bbc.com/arts
# Found link: https://www.bbc.com/travel
# Found link: https://www.bbc.com/future-planet
# Found link: https://www.bbc.com/video
# Found link: https://www.bbc.com/live
# Found link: https://www.bbc.co.uk/sounds
# Found link: https://www.bbc.com/weather
# Found link: https://shop.bbc.com/
# Found link: https://www.bbc.co.uk/usingthebbc/terms
# Found link: https://www.bbc.co.uk/aboutthebbc
# Found link: https://www.bbc.com/usingthebbc/privacy/
# Found link: https://www.bbc.com/usingthebbc/cookies/
# Found link: https://www.bbc.co.uk/accessibility/
# Found link: https://www.bbc.co.uk/contact
# Found link: https://www.bbc.com/advertisingcontact
# Found link: https://www.bbc.com/usingthebbc/cookies/how-can-i-change-my-bbc-cookie-settings/
# Found link: https://www.bbc.com/contact-bbc-com-help
# Found link: https://www.bbc.co.uk/editorialguidelines/guidance/feeds-and-links

# %%
Explanation of the Code:

URL Management: The function crawl_webpage() takes an initial URL, max_depth (maximum depth to crawl), and allowed_domains (optional list of domains to restrict crawling).

Fetching Web Pages: The requests.get(current_url) function fetches the webpage, and BeautifulSoup parses the HTML to extract links.

Link Filtering: The urlparse function is used to extract the domain from the URL to ensure we only crawl links within the allowed domains (if provided).

Crawl Depth: The crawling process continues to the next level by appending the link to urls_to_visit until the maximum depth is reached.

Additional Considerations:

User Input: You can modify the code to take user input for the search term (e.g., news topic) and filter links based on that.

Data Storage: For a real-world application, you would typically store the crawled data (like news articles) into a database or 
file system for further processing (e.g., sentiment analysis or topic classification).


Web crawling refers to the process of automatically navigating the web and collecting information from websites. 
This technique is essential for search engines, data extraction, and many other applications where automated access to the internet is required.

When it comes to gathering news stories on a specific topic, the process typically involves the following steps:

Web Crawling: Using an automated crawler to visit websites and extract news articles based on the given topic.
HTML Parsing: Extracting relevant content (e.g., headlines, articles) from the HTML structure of the pages using a parser.
Filtering: Allowing the user to limit the crawl to specific websites or domains. 
This is particularly important when focusing on collecting news from trusted sources.

Storing Results: Saving the collected news stories for further processing, analysis, or display.

For this experiment, we use the Python libraries requests and BeautifulSoup for crawling and parsing HTML content. 
requests allows us to fetch the content from URLs, while BeautifulSoup is used to parse the HTML content and extract useful information.
